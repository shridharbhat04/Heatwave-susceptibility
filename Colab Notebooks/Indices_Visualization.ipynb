# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('API.csv')

category_counts = df['Category'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette='magma')

plt.title('Count of States by Air Quality Category', size=16)
plt.xlabel('Air Quality Category')
plt.ylabel('Count of States')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-13-ab9bfa8743bd>:5: DtypeWarning: Columns (0,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('API.csv')
# <ipython-input-13-ab9bfa8743bd>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette='magma')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('CEIS.csv')

category_counts = df['CEIS Category'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')

plt.title('Count of States by Carbon Emmision Category', size=16)
plt.xlabel('Carbon Emmision Category')
plt.ylabel('Count of States')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-17-622608200f06>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('GSS.csv')

category_counts = df['Category'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette='Blues')

plt.title('Count of States by Groundwater Category', size=16)
plt.xlabel('Groundwater Category')
plt.ylabel('Count of States')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-20-77b45a1b7bc8>:5: DtypeWarning: Columns (0,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('GSS.csv')
# <ipython-input-20-77b45a1b7bc8>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette='Blues')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('PDI.csv')

category_counts = df['Category'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette='coolwarm')

plt.title('Count of States by Population Category', size=16)
plt.xlabel('Population Category')
plt.ylabel('Count of States')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-23-e59891cf6846>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette='coolwarm')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('RSI.csv')

category_counts = df['Category'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette='Pastel1')

plt.title('Count of States by Rainfall Category', size=16)
plt.xlabel('Rainfall Category')
plt.ylabel('Count of States')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-25-4f66ad4e38c1>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette='Pastel1')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('TVS.csv')

category_counts = df['Category'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette='magma')

plt.title('Count of States by Temperature Category', size=16)
plt.xlabel('Temperature Category')
plt.ylabel('Count of States')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-26-526922abd535>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette='magma')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('WHI.csv')

category_counts = df['Category'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette='Blues')

plt.title('Count of States by Health Category', size=16)
plt.xlabel('Health Category')
plt.ylabel('Count of States')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-28-db78d174b8d8>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette='Blues')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('heatwave_score.csv')

plt.figure(figsize=(12, 6))
sns.barplot(x='State', y='Heatwave Susceptiblity Score', data=df, palette='viridis')

plt.title('Heatwave Susceptiblity Score Across States', size=16)
plt.xlabel('State')
plt.ylabel('Heatwave Susceptiblity Score')
plt.xticks(rotation=90)
plt.tight_layout()

plt.show()
# Out:
# <ipython-input-37-a36fa8f8767f>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='State', y='Heatwave Susceptiblity Score', data=df, palette='viridis')
